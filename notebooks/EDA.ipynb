# %%
import pandas as pd

# %%
## Data Ingestions
df= pd.read_csv('data/gemstone.csv')

# %%
df.head(1)
# Out:
#    id  carat      cut color clarity  depth  table     x     y     z  price
# 0   0   1.52  Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
## No Missing data in gemstone dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
df=df.drop(labels=['id'], axis=1)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
## Check for duplicated records
df.duplicated().sum()
#df.drop.duplicates
# Out:
# 0

# %%
## segregate numerical and categorical 
numerical_coulumns = df.columns[df.dtypes!='object']
categorical_colmnns = df.columns[df.dtypes=='object']
print('numerical columns', numerical_coulumns)
print('categorical_columns', categorical_colmnns)
# Out:
# numerical columns Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# categorical_columns Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[categorical_colmnns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
df['cut'].nunique()
# Out:
# 5

# %%
df['cut'].value_counts()
# Out:
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: cut, dtype: int64

# %%
df['color'].value_counts()
# Out:
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: color, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
x=1
for i in numerical_coulumns:
    sns.histplot(data=df, x=i, kde=True)
    print('\n')
    plt.show()

# %%
for i in numerical_coulumns:
    sns.distplot(df[numerical_coulumns])
    print('\n')
    plt.show()
# Out:
# c:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
### do the same for categorocal data

# %%
sns.set_theme(style="ticks", color_codes=True)

# %%
categorical_colmnns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
sns.catplot(x='cut', y='color', data=df)

# %%
sns.catplot(x='cut', y='clarity',hue="color", data=df)

# %%
sns.catplot(x='cut', y='price',hue='color', kind='bar', data=df)

# %%
sns.catplot(y="cut", hue="color", kind="count",
            palette="pastel", edgecolor=".6",
            data=df)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %%
#df.drop(labels=['x','y','z'], axis=1)
#we can drop highly correlated independent features otherwise it will overfit
#This is called multi colinearity

# %%
sample =df.sample(frac=0.2)

# %%
len(sample)
# Out:
# 38715

# %%
len(df)
# Out:
# 193573

# %%
sns.pairplot(sample)

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map= {'Fair':1, 'Good':2, 'Very Good':3, 'Premium':4, 'Ideal':5}

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map = {'I1':1, 'SI2':2, 'SI1':3, 'VS2':4, 'VS1':5,'VVS2':6, 'VVS1':7, 'IF':8 }

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map = {'D':1, 'E':2, 'F':3,'G':4, 'H':5, 'I':6, 'J':7 }

# %%
df['cut'] = df['cut'].map(cut_map)
df['clarity'] = df['clarity'].map(clarity_map)
df['color'] = df['color'].map(color_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 10 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   carat    193573 non-null  float64
#  1   cut      193573 non-null  int64
#  2   color    193573 non-null  int64
#  3   clarity  193573 non-null  int64
#  4   depth    193573 non-null  float64
#  5   table    193573 non-null  float64
#  6   x        193573 non-null  float64
#  7   y        193573 non-null  float64
#  8   z        193573 non-null  float64
#  9   price    193573 non-null  int64
# dtypes: float64(6), int64(4)
# memory usage: 14.8 MB
